# %% [markdown]
# <a href="https://colab.research.google.com/github/slowanimals/ATBS/blob/main/D2L_Preliminaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch==2.0.0 torchvision==0.15.1
# !pip install d2l==1.0.3
